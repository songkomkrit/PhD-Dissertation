# %%
import os.path
import urllib.request
import re
import pandas as pd
import json
import warnings

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
warnings.filterwarnings('ignore')

# %%
def import_dict(metadata):
    with open(metadata) as myfile:
    	indep_contents = myfile.read()
    return json.loads(indep_contents)

def import_dataset(dataset):
    df0 = pd.read_sas(dataset)
    print(f"Number of original data: {len(df0)}")
    df0 = df0[df0['COV']!=0]
    print(f"An infant born after calendar year (COV = 0) is excluded")
    print(f"Number of training data: {len(df0)}")
    return df0

def code_df(df0, indep_dict, dep_attrs):
    df1 = pd.DataFrame(index = df0.index)
    for v in indep_dict.keys():
        if indep_dict[v]['type'] == 'Categorical':
            df1[v] = df0[v].astype('int8').astype('category')
        elif max(df0[v]) <= 65504 and min(df0[v]) >= -65504:
            df1[v] = df0[v].astype('float16')
        else:
            df1[v] = df0[v].astype('float32')
    df1[dep_attrs] = df0[dep_attrs].astype('int8')
    df1['class'] = 0
    df1['code'] = ""
    for v in dep_attrs:
    	df1[v] = df1[v].replace([2.0, 1.0], [False, True])
    	df1['class'] = 2*df1['class'] + df1[v]
    	df1['code'] = df1['code'] + df1[v].replace([True, False], ['Y', 'N'])
    df1[dep_attrs] = df1[dep_attrs].astype('category')
    df1['class'] = df1['class'].astype('int8').astype('category')
    df1['code'] = df1['code'].astype('category')
    return df1

def recode_df(df1):
    df2 = df1.copy()
    df2['code_new'] =  df2['code'].apply(
        lambda v: 'NY_' if re.match('(NY)', v) 
        else 'Y1Y' if re.match('^Y(?:\w*Y)', v)  
        else v
    )
    df2['code_new'] = df2['code_new'].astype('category')
    df2['class_new'] =  df2[['class', 'code_new']].apply(
        lambda v: 2 if v['code_new'] == 'NY_'
        else 3 if v['code_new'] == 'YNN'
        else 4 if v['code_new'] == 'Y1Y'
        else v['class'], 
        axis=1
    )
    df2['class_new'] = df2['class_new'].astype('int8').astype('category')
    return df2

def type_df(df, option='short'):
    if option.lower() == 'full':
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):
            print(df.dtypes)
    else:
        print(df.dtypes)

# %%
if not os.path.isfile('pppub20.sas7bdat'):
    urllib.request.urlretrieve('https://filedn.eu/lrP6X4gzwLByok9WpRTqaG8/pppub20.sas7bdat', 'pppub20.sas7bdat')

# %%
indep_dict = import_dict(metadata='meta-indep.json')
dep_attrs = ['GRP', 'DIR', 'PUB']
df0 = import_dataset(dataset='pppub20.sas7bdat')
# Out:
# Number of original data: 157959
# An infant born after calendar year (COV = 0) is excluded
# Number of training data: 157681

# %%
num_cat = 0
num_cont = 0
for key in indep_dict:
    if indep_dict[key]['type'] == 'Categorical':
        num_cat += 1
    else:
        num_cont += 1
print(f"There are {num_cat + num_cont} independent variables of interest: {num_cat} categorical and {num_cont} continuous")
# Out:
# There are 184 independent variables of interest: 118 categorical and 66 continuous

# %%
df1 = code_df(df0, indep_dict, dep_attrs)
df = recode_df(df1)

# %%
type_df(df, option='full')
# Out:
# A_AGE            float16
# A_EXPRRP        category
# A_FAMTYP        category
# A_HGA           category
# A_MARITL        category
# A_PFREL         category
# A_SEX           category
# P_STAT          category
# PEAFEVER        category
# PEDISDRS        category
# PEDISEAR        category
# PEDISEYE        category
# PEDISOUT        category
# PEDISPHY        category
# PEDISREM        category
# PRDISFLG        category
# PRCITSHP        category
# PRDTRACE        category
# A_MJIND         category
# A_MJOCC         category
# PEIO1COW        category
# PRDISC          category
# PRUNTYPE        category
# A_GRSWK          float16
# A_HRLYWK        category
# A_HRSPAY         float16
# PRERELG         category
# A_CIVLF         category
# A_CLSWKR        category
# A_EXPLF         category
# A_LFSR          category
# A_UNCOV         category
# A_UNMEM         category
# A_UNTYPE        category
# A_USLHRS         float16
# A_WKSCH         category
# A_WKSLK          float16
# A_WKSTAT        category
# PEHRUSLT         float16
# PEMLR           category
# PRCOW1          category
# PRPTREA         category
# PRWKSTAT        category
# CLWK            category
# EARNER          category
# HRSWK            float16
# LJCW            category
# NWLKWK           float16
# NWLOOK          category
# PHMEMPRS        category
# RSNNOTW         category
# WECLW           category
# WEWKRS          category
# WKSWORK          float16
# WORKYN          category
# WRK_CK          category
# WTEMP           category
# ERN_OTR         category
# ERN_SRCE        category
# ERN_VAL          float32
# ERN_YN          category
# FRM_VAL          float32
# FRMOTR          category
# FRSE_VAL         float32
# FRSE_YN         category
# PEARNVAL         float32
# SE_VAL           float32
# SEMP_VAL         float32
# SEMP_YN         category
# SEOTR           category
# WAGEOTR         category
# WS_VAL           float32
# WSAL_VAL         float32
# WSAL_YN         category
# ANN_VAL          float32
# ANN_YN          category
# CAP_VAL          float32
# CAP_YN          category
# DBTN_VAL         float32
# DIS_SC1         category
# DIS_SC2         category
# DIS_VAL1         float32
# DIS_VAL2         float16
# DIS_YN          category
# DIV_VAL          float32
# DIV_YN          category
# DSAB_VAL         float32
# DST_SC1         category
# DST_SC1_YNG     category
# DST_SC2         category
# DST_SC2_YNG     category
# DST_VAL1         float32
# DST_VAL1_YNG     float32
# DST_VAL2         float32
# DST_VAL2_YNG     float16
# DST_YN          category
# DST_YN_YNG      category
# ED_VAL           float32
# ED_YN           category
# FIN_VAL          float32
# FIN_YN          category
# INT_VAL          float32
# INT_YN          category
# OED_TYP1        category
# OED_TYP2        category
# OED_TYP3        category
# OI_OFF          category
# OI_VAL           float32
# OI_YN           category
# PEN_SC1         category
# PEN_SC2         category
# PEN_VAL1         float32
# PEN_VAL2         float32
# PEN_YN          category
# PNSN_VAL         float32
# PTOTVAL          float32
# RESNSS1         category
# RESNSS2         category
# RESNSSI1        category
# RESNSSI2        category
# RETCB_VAL        float16
# RETCB_YN        category
# RINT_SC1        category
# RINT_SC2        category
# RINT_VAL1        float32
# RINT_VAL2        float32
# RINT_YN         category
# RNT_VAL          float32
# RNT_YN          category
# SRVS_VAL         float32
# SS_VAL           float32
# SS_YN           category
# SSI_VAL          float16
# SSI_YN          category
# STRKUC          category
# SUBUC           category
# SUR_SC1         category
# SUR_SC2         category
# SUR_VAL1         float32
# SUR_VAL2         float32
# SUR_YN          category
# TRDINT_VAL       float32
# UC_VAL           float32
# UC_YN           category
# VET_TYP1        category
# VET_TYP2        category
# VET_TYP3        category
# VET_TYP4        category
# VET_TYP5        category
# VET_VAL          float32
# VET_YN          category
# WC_TYPE         category
# WC_VAL           float32
# WC_YN           category
# PAW_TYP         category
# PAW_VAL          float16
# PAW_YN          category
# PENINCL         category
# PENPLAN         category
# WICYN           category
# CHCARE_YN       category
# CHELSEW_YN      category
# CHSP_VAL         float32
# CHSP_YN         category
# CSP_VAL          float32
# CSP_YN          category
# ACTC_CRD         float16
# AGI              float32
# CTC_CRD          float16
# EIT_CRED         float16
# FED_RET          float16
# FEDTAX_AC        float32
# FEDTAX_BC        float32
# FICA             float16
# FILESTAT        category
# MARG_TAX         float16
# PRSWKXPNS        float16
# STATETAX_A       float32
# STATETAX_B       float32
# TAX_INC          float32
# PERLIS          category
# POV_UNIV        category
# HEA             category
# SPM_ACTC         float16
# GRP             category
# DIR             category
# PUB             category
# class           category
# code            category
# code_new        category
# class_new       category
# dtype: object

# %%
df[['GRP','DIR','PUB','class','code','code_new','class_new']].drop_duplicates().sort_values('class').reset_index(drop=True)
# Out:
#      GRP    DIR    PUB class code code_new class_new
# 0  False  False  False     0  NNN      NNN         0
# 1  False  False   True     1  NNY      NNY         1
# 2  False   True  False     2  NYN      NY_         2
# 3  False   True   True     3  NYY      NY_         2
# 4   True  False  False     4  YNN      YNN         3
# 5   True  False   True     5  YNY      Y1Y         4
# 6   True   True  False     6  YYN      Y1Y         4
# 7   True   True   True     7  YYY      Y1Y         4

# %%
print(f"Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)")
print("\n")
print(df1.groupby('code').size())
print("\n")
print(df.groupby('code_new').size())
print("\n-----------------------------------------")
# Out:
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
#
#
# code
# NNN    15035
# NNY    38745
# NYN     8084
# NYY     6157
# YNN    80165
# YNY     8206
# YYN     1104
# YYY      185
# dtype: int64
#
#
# code_new
# NNN    15035
# NNY    38745
# NY_    14241
# Y1Y     9495
# YNN    80165
# dtype: int64
#
# -----------------------------------------

# %%
for v in indep_dict.keys():
    if indep_dict[v]['type'] == "Categorical":
        dat_tab = pd.crosstab(index=df[v].map(lambda x: indep_dict[v]['values'][str(x)]), columns=df['code_new'])
    else:
        dat = df[[v, 'code_new']].copy()
        bins = 10
        dat['bins'] = pd.cut(dat[v], bins)
        dat_tab = pd.crosstab(index=dat['bins'],columns=dat['code_new'])
        del dat
    print(v)
    print(f"Label: {indep_dict[v]['label']}")
    print(f"Universe: {indep_dict[v]['universe']}")
    print(f"Type: {indep_dict[v]['type']}")
    print(f"Topic: {indep_dict[v]['topic']}")
    print(f"Subtopic: {indep_dict[v]['subtopic']}")
    print(f"Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)")
    print(dat_tab)
    print("\n-----------------------------------------")
    del dat_tab
# Out:
# A_AGE
# Label: Age
# Universe: All Persons
# Type: Continuous
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN   NNY   NY_   Y1Y    YNN
# bins
# (-0.085, 8.5]  1407  5834   789   628   9795
# (8.5, 17.0]    1557  6237  1079   770  11822
# (17.0, 25.5]   2238  2475  1043   414   8017
# (25.5, 34.0]   2635  2749  1082   594  10611
# (34.0, 42.5]   2271  2146   976   613  11509
# (42.5, 51.0]   2109  2171  1157   518  12081
# (51.0, 59.5]   1606  2403  1223   471   9864
# (59.5, 68.0]   1028  4854  2313  2090   6097
# (68.0, 76.5]    105  5404  2602  2044    254
# (76.5, 85.0]     79  4472  1977  1353    115
#
# -----------------------------------------
# A_EXPRRP
# Label: Expanded relationship code
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                             NNN    NNY   NY_   Y1Y    YNN
# A_EXPRRP
# Reference person with relatives     3693   8822  4254  3365  21403
# Reference person without relatives  1603   6102  2739  1413   7066
# Husband                             1049   2196  1325  1016   7069
# Wife                                1482   2898  1984  1426  10471
# Own child                           4337  12355  2540  1553  27291
# Grandchild                           377   1621   137   106    940
# Parent                               335   1183   305   174    780
# Brother/sister                       352    636   127    50    680
# Other relative                       464   1219   215   106    908
# Foster child                           2    107     2    44      2
# Nonrelative with relatives           305    514   101    73    816
# Partner/roommate                     803    780   421   149   2381
# Nonrelative without relatives        233    312    91    20    358
#
# -----------------------------------------
# A_FAMTYP
# Label: Family type
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                 NNN    NNY    NY_   Y1Y    YNN
# A_FAMTYP
# Primary family         11310  28667  10560  7564  67373
# Nonfamily householder   1603   6102   2739  1413   7066
# Related subfamily        779   2263    327   232   2169
# Unrelated subfamily       59    175     32    29    223
# Secondary individual    1284   1538    583   257   3334
#
# -----------------------------------------
# A_HGA
# Label: Educational attainment
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                             NNN    NNY   NY_   Y1Y    YNN
# A_HGA
# Children                                            2431  10167  1488  1160  17629
# Less than 1st grade                                   76    177    31    19     64
# 1st,2nd,3rd,or 4th grade                             170    390    61    21    115
# 5th or 6th grade                                     412    666   105    52    283
# 7th and 8th grade                                    418   1035   222   116    794
# 9th grade                                            480   1208   231   126   1381
# 10th grade                                           459   1363   252   169   1694
# 11th grade                                           495   1443   307   172   1814
# 12th grade no diploma                                339    716   159    94    794
# High school graduate - high school diploma or e...  4267   9614  3563  2174  13304
# Some college but no degree                          2177   4642  2282  1357  10203
# Associate degree in college - occupation/vocati...   465   1044   589   370   2681
# Associate degree in college - academic program       610   1260   719   513   3919
# Bachelor's degree (for example: BA,AB,BS)           1580   3364  2738  1731  15745
# Master's degree (for example: MA,MS,MENG,MED,MS...   530   1221  1041  1017   7264
# Professional school degree (for example: MD,DDS...    52    189   202   162   1026
# Doctorate degree (for example: PHD,EDD)               74    246   251   242   1455
#
# -----------------------------------------
# A_MARITL
# Label: Marital status
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                  NNN    NNY   NY_   Y1Y    YNN
# A_MARITL
# Married - civilian spouse present        4911  11026  6899  5333  35669
# Married - AF spouse present               346     11     9     0     86
# Married - spouse absent (exc.separated)   261    418   175    97    721
# Widowed                                   282   3671  1344   784    741
# Divorced                                 1186   3834  1402   754   4817
# Separated                                 356    723   144   101    758
# Never married                            7693  19062  4268  2426  37373
#
# -----------------------------------------
# A_PFREL
# Label: Primary family relationship
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                     NNN    NNY   NY_   Y1Y    YNN
# A_PFREL
# Not in primary family       2946   7815  3354  1699  10623
# Husband                     2408   5385  3324  2794  16972
# Wife                        2501   4998  3382  2404  17664
# Own child                   4337  12355  2540  1553  27291
# Other relative              1528   4659   784   436   3308
# Unmarried reference person  1315   3533   857   609   4307
#
# -----------------------------------------
# A_SEX
# Label: Sex
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new   NNN    NNY   NY_   Y1Y    YNN
# A_SEX
# Male      7804  17947  6658  4710  39664
# Female    7231  20798  7583  4785  40501
#
# -----------------------------------------
# P_STAT
# Label: Status of person identifier
# Universe: All Persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new         NNN    NNY    NY_   Y1Y    YNN
# P_STAT
# Civilian 15+   12186  28562  12747  8334  62431
# Armed forces     418     16      6     1    105
# Children 0-14   2431  10167   1488  1160  17629
#
# -----------------------------------------
# PEAFEVER
# Label: Did you ever serve on active duty in the U.S. Armed Forces?
# Universe: A_AGE greater than or equal to 17
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEAFEVER
# Not in universe   3207  11462   1745  1320  20376
# Yes                674   3025   1158  1233   2498
# No               11154  24258  11338  6942  57291
#
# -----------------------------------------
# PEDISDRS
# Label: Does...have difficulty dressing or bathing?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISDRS
# Not in universe   2849  10183   1494  1161  17734
# Yes                 98   1545    299   233    224
# No               12088  27017  12448  8101  62207
#
# -----------------------------------------
# PEDISEAR
# Label: Is...deaf or does ...have serious difficulty hearing?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISEAR
# Not in universe   2849  10183   1494  1161  17734
# Yes                153   2024    809   573    683
# No               12033  26538  11938  7761  61748
#
# -----------------------------------------
# PEDISEYE
# Label: Is...blind or does...have serious difficulty seeing even when wearing glasses?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISEYE
# Not in universe   2849  10183   1494  1161  17734
# Yes                110   1116    280   202    358
# No               12076  27446  12467  8132  62073
#
# -----------------------------------------
# PEDISOUT
# Label: Because of a physical, mental, or emotional condition, does...have difficulty doing errands along such as visiting a doctor’s office or shopping?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISOUT
# Not in universe   2849  10183   1494  1161  17734
# Yes                223   3156    638   513    506
# No               11963  25406  12109  7821  61925
#
# -----------------------------------------
# PEDISPHY
# Label: Does...have serious difficulty Walking or climbing stairs?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISPHY
# Not in universe   2849  10183   1494  1161  17734
# Yes                339   4767   1210   900    933
# No               11847  23795  11537  7434  61498
#
# -----------------------------------------
# PEDISREM
# Label: Because of a physical, mental, or emotional condition, does...have serious difficulty concentrating, remembering, or making decisions?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PEDISREM
# Not in universe   2849  10183   1494  1161  17734
# Yes                292   2489    519   367    762
# No               11894  26073  12228  7967  61669
#
# -----------------------------------------
# PRDISFLG
# Label: Does this person have any of these disability conditions?
# Universe: PRPERTYP = 2
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY    NY_   Y1Y    YNN
# PRDISFLG
# Not in universe   2849  10183   1494  1161  17734
# Yes                732   7560   2124  1569   2395
# No               11454  21002  10623  6765  60036
#
# -----------------------------------------
# PRCITSHP
# Label: Citizenship group
# Universe: All persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                  NNN    NNY    NY_   Y1Y    YNN
# PRCITSHP
# Native, born in US                      11006  32887  12065  8403  70326
# Native, born in PR or US outlying area     82    345     60    49    326
# Native, born abroad of US parent(s)       153    249     92    76    694
# Foreign born, US cit by naturalization   1004   2975   1067   650   4851
# Foreign born, not a US citizen           2790   2289    957   317   3968
#
# -----------------------------------------
# PRDTRACE
# Label: Race
# Universe: All persons
# Type: Categorical
# Topic: Demographics
# Subtopic: Individual characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                     NNN    NNY    NY_   Y1Y    YNN
# PRDTRACE
# White only                                 11466  27682  11885  7517  63366
# Black only                                  1765   6815   1011  1051   7484
# American Indian, Alaskan Native only (AI)    516    902     97    85    837
# Asian only                                   745   2010    962   561   5947
# Hawaiian/Pacific Islander only (HP)           89    192     34    41    368
# White-Black                                  150    428     70    58    600
# White-AI                                     131    351     81    96    490
# White-Asian                                   86    111     52    41    613
# White-HP                                      17     50     15    13    112
# Black-AI                                      26     67      5    12     58
# Black-Asian                                    2      8      9     3     45
# Black-HP                                       1      8      1     4      1
# AI-Asian                                       2      6      1     0      6
# AI-HP                                          0      4      0     0      4
# Asian-HP                                       5     17     12     7     72
# White-Black-AI                                13     44      2     3     32
# White-Black-Asian                             12      8      0     1     34
# White-Black-HP                                 0      1      0     0      5
# White-AI-Asian                                 2      3      0     0      7
# White-AI-HP                                    0      3      0     0      4
# White-Asian-HP                                 4     35      1     2     65
# Black-AI-Asian                                 1      0      0     0      1
# White-Black-AI-Asian                           0      0      2     0      5
# Other 3 race comb.                             1      0      0     0      3
# Other 4 or 5 race comb.                        1      0      1     0      6
#
# -----------------------------------------
# A_MJIND
# Label: Major industry code
# Universe: A_CLSWKR = 1-7
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited labor force items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                     NNN    NNY   NY_   Y1Y    YNN
# A_MJIND
# Not in universe, or children                6704  30326  8393  5873  29260
# Agriculture, forestry,fishing, and hunting   268    241   309    79    536
# Mining                                        44     21    24    18    445
# Construction                                1114    670   511   214   2961
# Manufacturing                                551    501   331   346   5528
# Wholesale and retail trade                  1124   1336   770   433   5857
# Transportation and utilities                 480    474   276   185   2865
# Information                                   80    117    93    48    978
# Financial activities                         310    336   437   233   3752
# Professional and business services           957    926   813   414   6036
# Educational and health services             1209   1607  1088   957  13296
# Leisure and hospitality                     1346   1367   629   278   3561
# Other services                               589    615   457   185   1854
# Public administration                        250    208   110   232   3236
# Armed forces                                   9      0     0     0      0
#
# -----------------------------------------
# A_MJOCC
# Label: Major occupation recode
# Universe: A_CLSWKR = 1-7
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited labor force items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                            NNN    NNY   NY_   Y1Y    YNN
# A_MJOCC
# Not in universe or children                        6704  30326  8393  5873  29260
# Management, business, and financial occupations     866    821  1144   595   9953
# Professional and related occupations                964   1023  1142   951  14527
# Service occupations                                2265   2597  1125   547   6665
# Sales and related occupations                       791   1025   687   311   4343
# Office and administrative support occupations       661    797   589   423   5469
# Farming, fishing, and forestry occupations          177    123    95    31    246
# Construction and extraction occupations             948    536   326   160   2154
# Installation, maintenance, and repair occupations   327    215   129   127   1622
# Production occupations                              484    417   228   194   2728
# Transportation and material moving occupations      839    865   383   283   3198
# Armed forces                                          9      0     0     0      0
#
# -----------------------------------------
# PEIO1COW
# Label: Individual class of worker on first job
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited labor force items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                        NNN    NNY   NY_   Y1Y    YNN
# PEIO1COW
# NIU                            6704  30326  8393  5873  29260
# Government-federal              222    120    57   138   1708
# Government-state                189    237   151   213   3210
# Government - local              219    337   196   296   4045
# Private, for profit            6214   5951  3369  2233  34815
# Private, nonprofit              274    466   323   343   3933
# Self-employed, incorporated     325    323   756   152   1484
# Self-employed, unincorporated   880    974   986   246   1703
# Without pay                       8     11    10     1      7
#
# -----------------------------------------
# PRDISC
# Label: Discouraged worker recode
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited labor force items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                    NNN    NNY    NY_   Y1Y    YNN
# PRDISC
# NIU                       14880  38437  14165  9452  79861
# Discouraged worker           40     83     18     4     57
# Conditionally interested     73    159     34    28    145
# Not available                42     66     24    11    102
#
# -----------------------------------------
# PRUNTYPE
# Label: Individual class of worker on first job
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited labor force items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new               NNN    NNY    NY_   Y1Y    YNN
# PRUNTYPE
# NIU                  14304  37763  13967  9302  78459
# Job loser/on layoff    252    341    136    72    797
# Other job loser        127    130     38    52    329
# Temporary job ended     82     97     17    14     93
# Job leaver              69     64     14    11    138
# Re-entrant             162    266     62    38    275
# New-entrant             39     84      7     6     74
#
# -----------------------------------------
# A_GRSWK
# Label: How much does ... usually earn per week at this job before deductions , subject to topcoding, the higher of either the amount of item 25a times Item 25c or the actual item 25d entry will be present
# Universe: PRERELG=1
# Type: Continuous
# Topic: Basic CPS items
# Subtopic: Edited earnings items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new            NNN    NNY    NY_   Y1Y    YNN
# bins
# (-2.884, 288.4]   14066  37929  13596  9036  72547
# (288.4, 576.8]      405    397    211   109   1146
# (576.8, 865.2]      292    223    166   125   1691
# (865.2, 1153.6]     108     84     93    85   1400
# (1153.6, 1442.0]     67     51     51    43   1101
# (1442.0, 1730.4]     33     18     31    24    654
# (1730.4, 2018.8]     21     15     22    19    456
# (2018.8, 2307.2]     10      9     11     4    237
# (2307.2, 2595.6]     13      4     21    14    270
# (2595.6, 2884.0]     20     15     39    36    663
#
# -----------------------------------------
# A_HRLYWK
# Label: Is ... paid by the hour on this job?
# Universe: PRERELG=1
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited earnings items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                        NNN    NNY    NY_   Y1Y    YNN
# A_HRLYWK
# Not in universe or children and armed forces  13245  37057  13165  8715  67548
# Yes                                            1320   1289    662   468   6463
# No                                              470    399    414   312   6154
#
# -----------------------------------------
# A_HRSPAY
# Label: How much does ... earn per hour?
# Universe: A_HRLYWK=1
# Type: Continuous
# Topic: Basic CPS items
# Subtopic: Edited earnings items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new            NNN    NNY    NY_   Y1Y    YNN
# bins
# (-10.905, 989.5]  14314  38046  13813  9201  76286
# (989.5, 1980.0]     563    582    312   203   2118
# (1980.0, 2970.5]    113     80     69    58   1059
# (2970.5, 3961.0]     27     24     20    19    389
# (3961.0, 4951.5]     10      6     12     5    165
# (4951.5, 5942.0]      5      4     10     6     76
# (5942.0, 6932.5]      3      1      2     2     40
# (6932.5, 7923.0]      0      1      1     1     21
# (7923.0, 8913.5]      0      0      0     0      7
# (8913.5, 9904.0]      0      1      2     0      4
#
# -----------------------------------------
# PRERELG
# Label: Earnings eligibility flag
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Edited earnings items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                 NNN    NNY    NY_   Y1Y    YNN
# PRERELG
# Not earnings eligible  13245  37057  13165  8715  67548
# Earnings eligible       1790   1688   1076   780  12617
#
# -----------------------------------------
# A_CIVLF
# Label: Civilian labor force
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                       NNN    NNY   NY_   Y1Y    YNN
# A_CIVLF
# Not in universe or children and Armed Forces  6798  30466  8496  5960  29588
# In universe                                   8237   8279  5745  3535  50577
#
# -----------------------------------------
# A_CLSWKR
# Label: Class of worker
# Universe: PEMLR=1-3 or (PEMLR=4-7 and person worked in the last 12 months)
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                       NNN    NNY   NY_   Y1Y    YNN
# A_CLSWKR
# Not in universe or children and armed forces  6665  30242  8386  5867  29186
# Private                                       6488   6417  3692  2576  38748
# Federal government                             222    120    57   138   1708
# State government                               189    237   151   213   3210
# Local government                               219    337   196   296   4045
# Self-employed-incorporated                     325    323   756   152   1484
# Self-employed-not incorporated                 880    974   986   246   1703
# Without pay                                      8     11    10     1      7
# Never worked                                    39     84     7     6     74
#
# -----------------------------------------
# A_EXPLF
# Label: Experienced labor force employment status
# Universe: PEMLR=1-4
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                         NNN    NNY   NY_   Y1Y    YNN
# A_EXPLF
# Not in experienced labor force  6837  30550  8503  5966  29662
# Employed                        7506   7297  5471  3342  48871
# Unemployed                       692    898   267   187   1632
#
# -----------------------------------------
# A_LFSR
# Label: Labor force status recode
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                       NNN    NNY   NY_   Y1Y    YNN
# A_LFSR
# Children or Armed Forces      2849  10183  1494  1161  17734
# Working                       7178   6826  5136  3181  46957
# With job, not at work          328    471   335   161   1914
# Unemployed, looking for work   479    641   138   121    909
# Unemployed, on layoff          252    341   136    72    797
# Nilf                          3949  20283  7002  4799  11854
#
# -----------------------------------------
# A_UNCOV
# Label: On this job, is ... covered by a union or employee association contract?
# Universe: A_UNMEM=2
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                        NNN    NNY    NY_   Y1Y    YNN
# A_UNCOV
# Not in universe or children and armed forces  13962  37715  13483  9016  72936
# Yes                                               8     11      8    10    108
# No                                             1065   1019    750   469   7121
#
# -----------------------------------------
# A_UNMEM
# Label: On this job, is ... a member of a labor union or of an employee association similar to a union?
# Universe: PRERELG=1
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                        NNN    NNY    NY_   Y1Y    YNN
# A_UNMEM
# Not in universe or children and armed forces  13909  37669  13451  8957  71925
# Yes                                              53     46     32    59   1011
# No                                             1073   1030    758   479   7229
#
# -----------------------------------------
# A_UNTYPE
# Label: Reason for unemployment
# Universe: A_LFSR=3 or 4
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                        NNN    NNY    NY_   Y1Y    YNN
# A_UNTYPE
# Not in universe or children and Armed Forces  14304  37763  13967  9302  78459
# Job loser - on layoff                           252    341    136    72    797
# Other job loser                                 209    227     55    66    422
# Job leaver                                       69     64     14    11    138
# Re-entrant                                      162    266     62    38    275
# New entrant                                      39     84      7     6     74
#
# -----------------------------------------
# A_USLHRS
# Label: How many hrs per week does ... usually work at this job?
# Universe: All persons
# Type: Continuous
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN    NNY   NY_   Y1Y    YNN
# bins
# (-4.103, 6.3]  8214  32313  9452  6448  33848
# (6.3, 16.6]     279    647   359   198   1392
# (16.6, 26.9]    641   1071   691   288   2360
# (26.9, 37.2]    935   1099   622   362   3750
# (37.2, 47.5]   4268   3105  2411  1848  32501
# (47.5, 57.8]    436    291   412   234   4378
# (57.8, 68.1]    186    149   189    74   1437
# (68.1, 78.4]     45     46    57    22    289
# (78.4, 88.7]     24     13    28    16    166
# (88.7, 99.0]      7     11    20     5     44
#
# -----------------------------------------
# A_WKSCH
# Label: Labor force by time worked or lost
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                NNN    NNY   NY_   Y1Y    YNN
# A_WKSCH
# Not in universe        6798  30466  8496  5960  29588
# At work                7178   6826  5136  3181  46957
# With job, not at work   328    471   335   161   1914
# Unemployed, seeks FT    618    722   197   136   1316
# Unemployed, seeks PT    113    260    77    57    390
#
# -----------------------------------------
# A_WKSLK
# Label: Duration of unemployment
# Universe: PEMLR=3 or 4
# Type: Continuous
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new         NNN    NNY    NY_   Y1Y    YNN
# bins
# (-0.099, 9.9]  14748  38340  14142  9435  79643
# (9.9, 19.8]      118    150     44    27    237
# (19.8, 29.7]      49     76     17    12    121
# (29.7, 39.6]      26     50      9     7     66
# (39.6, 49.5]      10     11      4     4     16
# (49.5, 59.4]      45     50     11     5     42
# (59.4, 69.3]       9     10      3     0      7
# (69.3, 79.2]       4      2      0     0      1
# (79.2, 89.1]       0      0      0     0      1
# (89.1, 99.0]      26     56     11     5     31
#
# -----------------------------------------
# A_WKSTAT
# Label: Full/part-time status
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                         NNN    NNY   NY_   Y1Y    YNN
# A_WKSTAT
# Children or Armed Forces                        2849  10183  1494  1161  17734
# Not in labor force                              3949  20283  7002  4799  11854
# Full-time schedules                             5715   4390  3714  2508  42413
# Part-time for economic reasons, usually FT       267    217   153    48    670
# Part-time for non-economic reasons, usually PT  1200   2313  1464   718   5257
# Part-time for economic reasons, usually PT       324    377   140    68    531
# Unemployed FT                                    618    722   197   136   1316
# Unemployed PT                                    113    260    77    57    390
#
# -----------------------------------------
# PEHRUSLT
# Label: Hours usually worked last week
# Universe: All persons
# Type: Continuous
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new         NNN    NNY   NY_   Y1Y    YNN
# bins
# (-4.144, 10.4]  8336  32561  9610  6541  34614
# (10.4, 24.8]     595   1159   671   330   2447
# (24.8, 39.2]    1147   1420   805   444   4613
# (39.2, 53.6]    4519   3253  2721  1976  35068
# (53.6, 68.0]     333    257   306   147   2691
# (68.0, 82.4]      87     76   102    42    583
# (82.4, 96.8]      14      7    12     8    106
# (96.8, 111.2]      4     11    13     7     36
# (111.2, 125.6]     0      0     1     0      7
# (125.6, 140.0]     0      1     0     0      0
#
# -----------------------------------------
# PEMLR
# Label: Major labor force recode
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                        NNN    NNY   NY_   Y1Y    YNN
# PEMLR
# NIU                            2849  10183  1494  1161  17734
# Employed - at work             7178   6826  5136  3181  46957
# Employed - absent               328    471   335   161   1914
# Unemployed - on layoff          252    341   136    72    797
# Unemployed - looking            479    641   138   121    909
# Not in labor force - retired    543  11004  5087  3754   1768
# Not in labor force - disabled   437   4110   405   359    732
# Not in labor force - other     2969   5169  1510   686   9354
#
# -----------------------------------------
# PRCOW1
# Label: Class of worker recode-job 1
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                NNN    NNY   NY_   Y1Y    YNN
# PRCOW1
# NIU                                    6704  30326  8393  5873  29260
# Federal govt                            222    120    57   138   1708
# State govt                              189    237   151   213   3210
# Local govt                              219    337   196   296   4045
# Private (incl. self-employed incorp.)  6813   6740  4448  2728  40232
# Self-employed, unincorp.                880    974   986   246   1703
# Without pay                               8     11    10     1      7
#
# -----------------------------------------
# PRPTREA
# Label: Detailed reason for part-time
# Universe: Part time workers
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                              NNN    NNY    NY_   Y1Y    YNN
# PRPTREA
# NIU                                                 12873  35620  12343  8513  71585
# Usually FT - slack work/business conditions           248    202    136    45    634
# Usually FT - seasonal work                             13      6     14     1     17
# Usually FT - job started/ended during week              6      9      3     2     19
# Usually FT - vacation/personal day                     90     87     60    57    970
# Usually FT - own illness/injury/medical appt          109    124     79    57    669
# Usually FT - holiday (religious or legal)               5      7      3     4     40
# Usually FT - child care problems                        4      5      7     7     52
# Usually FT - other fam/pers obligations                32     25     20    17    206
# Usually FT - labor dispute                              2      1      0     0      4
# Usually FT - weather affected job                      70     30     10     5     70
# Usually FT - school/training                            5      5      1     0     18
# Usually FT - civic/military duty                        0      1      0     0      4
# Usually FT - other reason                             119    116     74    44    446
# Usually PT - slack work/business conditions           206    223     95    40    345
# Usually PT - PT could only find PT work               133    177     61    30    233
# Usually PT - seasonal work                             12      7      5     2     12
# Usually PT - child care problems                       64    116     40    16    236
# Usually PT - other fam/pers obligations               271    343    248   111   1221
# Usually PT - health/medical limitations                51    199     54    44    123
# Usually PT - school/training                          303    450    245    98   1713
# Usually PT - retired/social security limit on e...     52    440    350   238    228
# Usually PT - workweek<35 hours                        260    407    251   106    952
# Usually PT - other                                    107    145    142    58    368
#
# -----------------------------------------
# PRWKSTAT
# Label: Full/part-time work status
# Universe: All persons
# Type: Categorical
# Topic: Basic CPS items
# Subtopic: Labor force person recodes
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                        NNN    NNY   NY_   Y1Y    YNN
# PRWKSTAT
# NIU                                            2849  10183  1494  1161  17734
# Not in labor force                             3949  20283  7002  4799  11854
# FT hours (35+), usually FT                     4995   3679  3226  2189  38324
# PT for economic reasons, usually FT             267    217   153    48    670
# PT for non-economic reasons, usually FT         436    401   254   191   2479
# Not at work, usually FT                         227    238   179   105   1389
# PT hrs, usually PT for economic reasons         324    377   140    68    531
# PT hrs, usually PT for non-economic            1099   2080  1308   662   4732
# FT hours, usually PT for economic reasons        17     16    12     1     29
# FT hours, usually PT for non-economic reasons    40     56    43    22    192
# Not at work, usually part-time                  101    233   156    56    525
# Unemployed FT                                   618    722   197   136   1316
# Unemployed PT                                   113    260    77    57    390
#
# -----------------------------------------
# CLWK
# Label: Longest job class of worker (recode)
# Universe: All persons aged 15+
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN    NNY   NY_   Y1Y    YNN
# CLWK
# Niu            2431  10167  1488  1160  17629
# Private        6959   7099  4733  3023  41294
# Government     1009    747   446   710   9436
# Self-employed   849    992  1008   253   1614
# Without pay      17     12    15     1     15
# Never worked   3770  19728  6551  4348  10177
#
# -----------------------------------------
# EARNER
# Label: Earner status recode
# Universe: All persons aged 15+
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new    NNN    NNY   NY_   Y1Y    YNN
# EARNER
# Niu        2431  10167  1488  1160  17629
# Earner     8821   8842  6188  3986  52346
# Nonearner  3783  19736  6565  4349  10190
#
# -----------------------------------------
# HRSWK
# Label: In the weeks that ... worked how may hours did ... usually work per week?
# Universe: WKSWORK > 0
# Type: Continuous
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN    NNY   NY_   Y1Y    YNN
# bins
# (-0.099, 9.9]  6347  30317  8296  5648  28472
# (9.9, 19.8]     354    837   443   259   1576
# (19.8, 29.7]    875   1550   858   390   2922
# (29.7, 39.6]   1277   1534   847   486   4780
# (39.6, 49.5]   5110   3719  2826  2191  34221
# (49.5, 59.4]    673    461   578   336   5584
# (59.4, 69.3]    276    228   263   122   1929
# (69.3, 79.2]     77     48    74    33    383
# (79.2, 89.1]     41     33    33    20    222
# (89.1, 99.0]      5     18    23    10     76
#
# -----------------------------------------
# LJCW
# Label: Longest job class of worker
# Universe: WKSWORK > 0
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                 NNN    NNY   NY_   Y1Y    YNN
# LJCW
# Niu                                     6201  29895  8039  5508  27806
# Private                                 6640   6757  3950  2866  40016
# Federal                                  569    142    63   152   1842
# State                                    208    249   160   236   3440
# Local                                    232    356   223   322   4154
# Self employed incorporated, yes          319    342   783   157   1278
# Self employed incorporated, no or farm   849    992  1008   253   1614
# Without pay                               17     12    15     1     15
#
# -----------------------------------------
# NWLKWK
# Label: How may different weeks was ... looking for work or on layoff?
# Universe: NWLOOK = 1
# Type: Continuous
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new         NNN    NNY    NY_   Y1Y    YNN
# bins
# (-0.052, 5.2]  14892  38462  14188  9469  79995
# (5.2, 10.4]       15     32      7     6     38
# (10.4, 15.6]      13     29      4     0     17
# (15.6, 20.8]       7     17      4     2      9
# (20.8, 26.0]      14     22      5     4     23
# (26.0, 31.2]       3      7      1     0      2
# (31.2, 36.4]       3      7      0     0      1
# (36.4, 41.6]       6     17      1     1      5
# (41.6, 46.8]       4      3      1     0      1
# (46.8, 52.0]      78    149     30    13     74
#
# -----------------------------------------
# NWLOOK
# Label: Even though ... did not work in 20.. did spend and time trying to find a job or on layoff?
# Universe: WORKYN = 2
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new    NNN    NNY   NY_   Y1Y    YNN
# NWLOOK
# Niu       11265  19017  7690  5147  69988
# Yes         176    340    70    41    236
# No         3594  19388  6481  4307   9941
#
# -----------------------------------------
# PHMEMPRS
# Label: For how many employers did ... work in 20..? if more than one at same time, only count it as one employer
# Universe: WKSWORK > 0
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new              NNN    NNY   NY_   Y1Y    YNN
# PHMEMPRS
# Niu                  6201  29895  8039  5508  27806
# One employer         7684   7738  5537  3439  47029
# Two employers         857    848   535   439   4433
# 3 or more employers   293    264   130   109    897
#
# -----------------------------------------
# RSNNOTW
# Label: What was the main reason ... did not work in 20..?
# Universe: WORKYN = 2
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new               NNN    NNY   NY_   Y1Y    YNN
# RSNNOTW
# Niu                  11265  19017  7690  5147  69988
# Ill or disabled        508   4721   503   449    681
# Retired                477  10319  4709  3378   1425
# Taking care of home   1331   1690   562   231   2816
# Going to school       1043   2510   658   254   4901
# Could not find work    209    286    39    21    147
# Other                  202    202    80    15    207
#
# -----------------------------------------
# WECLW
# Label: Longest job class of worker (persons 15+)
# Universe: All persons aged 15+
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                            NNN    NNY   NY_   Y1Y    YNN
# WECLW
# Not in universe                    2431  10167  1488  1160  17629
# Agriculture (Wage and salary)       220    198   181    60    482
# Agriculture (Self-employed)          51     58   120    32    106
# Agriculture (Unpaid)                  7      3     2     0      4
# Nonagriculture (Private household   100    138    60    18    133
# Nonagriculture (Other private)     6338   6452  3776  2801  39483
# Nonagriculture (Government)        1006    742   444   708   9407
# Nonagriculture (Self-employed)     1102   1250  1606   367   2733
# Nonagriculture (Unpaid)              10      9    13     1     11
# Nonagriculture (Never worked)      3770  19728  6551  4348  10177
#
# -----------------------------------------
# WEWKRS
# Label: Weeks worked recode
# Universe: All persons aged 15+
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                       NNN    NNY   NY_   Y1Y    YNN
# WEWKRS
# Niu                           2431  10167  1488  1160  17629
# Full-year worker (Full time)  5641   3827  3519  2265  41178
# Full-year worker (Part time)  1027   1832  1095   515   3717
# Part-year worker (Full time)  1259   1434   695   716   4156
# Part-year worker (Part time)   907   1757   893   491   3308
# Part-year worker (Nonworker)  3770  19728  6551  4348  10177
#
# -----------------------------------------
# WKSWORK
# Label: During 20.. in how many weeks did ... work even for a few hours? (include paid vacation and sick leave as work)
# Universe: Persons 15+ with WORKYN = 1
# Type: Continuous
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN    NNY   NY_   Y1Y    YNN
# bins
# (-0.052, 5.2]  6329  30179  8164  5588  28130
# (5.2, 10.4]     147    315   110    98    626
# (10.4, 15.6]    180    343   147   104    716
# (15.6, 20.8]    229    363   147   131    748
# (20.8, 26.0]    318    518   218   197    926
# (26.0, 31.2]    184    242   117    79    493
# (31.2, 36.4]    235    266   155   111    733
# (36.4, 41.6]    300    342   242   163   1138
# (41.6, 46.8]    267    292   165   126    986
# (46.8, 52.0]   6846   5885  4776  2898  45669
#
# -----------------------------------------
# WORKYN
# Label: Did ... work at a job or business at any time during 20..?
# Universe: All persons aged 15+
# Type: Categorical
# Topic: Work experience
# Subtopic: General
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new   NNN    NNY   NY_   Y1Y    YNN
# WORKYN
# Niu       2431  10167  1488  1160  17629
# Yes       8727   8684  6108  3938  52062
# No        3877  19894  6645  4397  10474
#
# -----------------------------------------
# WRK_CK
# ...
# (19999.8, 29999.7]      5     10      5     1     23
# (29999.7, 39999.6]      0      4      1     1     11
# (39999.6, 49999.5]      1      0      1     1      2
# (49999.5, 59999.4]      0      0      0     0      1
# (69999.3, 79999.2]      0      0      1     0      0
# (89999.1, 99999.0]      0      1      0     0      3
#
# -----------------------------------------
# CSP_YN
# Label: Did ... receive child support payments?
# Universe: All Persons aged 15+
# Type: Categorical
# Topic: Income
# Subtopic: Supplemental poverty measure
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new    NNN    NNY    NY_   Y1Y    YNN
# CSP_YN
# Niu        2431  10167   1488  1160  17629
# Yes         201    560    112   136   1080
# No        12403  28018  12641  8199  61456
#
# -----------------------------------------
# ACTC_CRD
# Label: Additional child tax credit
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new             NNN    NNY    NY_   Y1Y    YNN
# bins
# (-11.104, 1110.4]  13939  37125  13926  9144  78392
# (1110.4, 2220.8]     534    804    153   168    834
# (2220.8, 3331.2]     359    525    102   119    559
# (3331.2, 4441.6]     153    216     45    42    256
# (4441.6, 5552.0]      27     32      5    12     59
# (5552.0, 6662.4]      17     29      8     8     41
# (6662.4, 7772.8]       3      8      2     1     15
# (7772.8, 8883.2]       2      4      0     0      4
# (8883.2, 9993.6]       1      2      0     1      4
# (9993.6, 11104.0]      0      0      0     0      1
#
# -----------------------------------------
# AGI
# Label: Adjusted gross income
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                  NNN    NNY    NY_   Y1Y    YNN
# bins
# (-12341.073, 224208.3]  14924  38542  13917  9179  77141
# (224208.3, 458415.6]       89    171    256   278   2438
# (458415.6, 692622.9]       14     21     33    21    325
# (692622.9, 926830.2]        4      5     16     4     98
# (926830.2, 1161037.5]       4      5     11     9     87
# (1161037.5, 1395244.8]      0      0      4     2     56
# (1395244.8, 1629452.1]      0      1      1     2      7
# (1629452.1, 1863659.4]      0      0      1     0      1
# (1863659.4, 2097866.7]      0      0      1     0      6
# (2097866.7, 2332074.0]      0      0      1     0      6
#
# -----------------------------------------
# CTC_CRD
# Label: Child tax credit
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new              NNN    NNY    NY_   Y1Y    YNN
# bins
# (-18.0, 1800.0]     13956  38047  13477  8913  69728
# (1800.0, 3600.0]      646    462    418   331   5281
# (3600.0, 5400.0]      327    187    250   182   3844
# (5400.0, 7200.0]       73     40     78    52   1015
# (7200.0, 9000.0]       26      8     15    15    236
# (9000.0, 10800.0]       5      1      2     2     40
# (10800.0, 12600.0]      2      0      0     0     17
# (12600.0, 14400.0]      0      0      0     0      2
# (14400.0, 16200.0]      0      0      1     0      0
# (16200.0, 18000.0]      0      0      0     0      2
#
# -----------------------------------------
# EIT_CRED
# Label: Earn income tax credit
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new            NNN    NNY    NY_   Y1Y    YNN
# bins
# (-6.556, 655.6]   13787  36710  13872  9134  78356
# (655.6, 1311.2]     106    159     45    40    348
# (1311.2, 1966.8]    127    149     72    55    329
# (1966.8, 2622.4]    153    229     44    46    282
# (2622.4, 3278.0]    135    248     45    54    207
# (3278.0, 3933.6]    263    419     62    60    266
# (3933.6, 4589.2]     92    185     36    24    120
# (4589.2, 5244.8]     88    152     20    26     86
# (5244.8, 5900.4]    168    306     28    39    117
# (5900.4, 6556.0]    116    188     17    17     54
#
# -----------------------------------------
# FED_RET
# Label: Federal retirement payroll deduction
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new              NNN    NNY    NY_   Y1Y    YNN
# bins
# (-16.896, 1689.6]   15032  38744  14241  9491  80153
# (1689.6, 3379.2]        0      0      0     0      2
# (3379.2, 5068.8]        1      1      0     0      2
# (5068.8, 6758.4]        2      0      0     1      4
# (6758.4, 8448.0]        0      0      0     0      1
# (8448.0, 10137.6]       0      0      0     2      2
# (10137.6, 11827.2]      0      0      0     0      1
# (15206.4, 16896.0]      0      0      0     1      0
#
# -----------------------------------------
# FEDTAX_AC
# Label: Federal income tax liability, after all credits
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                 NNN    NNY    NY_   Y1Y    YNN
# bins
# (-10797.046, 69805.6]  15001  38684  14139  9415  79276
# (69805.6, 149610.2]       22     49     66    62    605
# (149610.2, 229414.8]       8      5     18     6     94
# (229414.8, 309219.4]       2      3      7     4     62
# (309219.4, 389024.0]       2      3      7     6     91
# (389024.0, 468828.6]       0      1      1     2     23
# (468828.6, 548633.2]       0      0      2     0      4
# (628437.8, 708242.4]       0      0      1     0      6
# (708242.4, 788047.0]       0      0      0     0      4
#
# -----------------------------------------
# FEDTAX_BC
# Label: Federal income tax liability, before credits
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                NNN    NNY    NY_   Y1Y    YNN
# bins
# (-788.047, 78804.7]   15006  38696  14150  9434  79411
# (78804.7, 157609.4]      18     37     59    43    473
# (157609.4, 236414.1]      7      5     14     6     96
# (236414.1, 315218.8]      2      3      7     4     62
# (315218.8, 394023.5]      2      3      7     6     90
# (394023.5, 472828.2]      0      1      1     2     19
# (472828.2, 551632.9]      0      0      2     0      4
# (630437.6, 709242.3]      0      0      1     0      6
# (709242.3, 788047.0]      0      0      0     0      4
#
# -----------------------------------------
# FICA
# Label: Social security retirement payroll deduction
# Universe: All persons
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new              NNN    NNY    NY_   Y1Y    YNN
# bins
# (-55.456, 5545.6]   14080  38087  12928  8678  63816
# (5545.6, 11091.2]     821    521    979   661  14088
# (11091.2, 16636.8]     98     99    209   123   1751
# (16636.8, 22182.4]     23     29     85    19    287
# (22182.4, 27728.0]      6      5     21     9     78
# (27728.0, 33273.6]      5      4     13     5    134
# (33273.6, 38819.2]      0      0      4     0      6
# (38819.2, 44364.8]      1      0      2     0      1
# (44364.8, 49910.4]      1      0      0     0      3
# (49910.4, 55456.0]      0      0      0     0      1
#
# -----------------------------------------
# FILESTAT
# Label: Tax filer status
# Universe: All persons
# Type: Categorical
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                    NNN    NNY   NY_   Y1Y    YNN
# FILESTAT
# Joint, both<65             4721   3600  2931  1621  33473
# Joint, one ><65 & one 65+   235   1045   692   782   1812
# Joint, both 65+              67   3661  2693  2660    271
# Head of household           764   1485   350   299   3024
# Single                     4246   5595  3652  1956  17561
# Non-filer                  5002  23359  3923  2177  24024
#
# -----------------------------------------
# MARG_TAX
# Label: Marginal tax rate
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new        NNN    NNY   NY_   Y1Y    YNN
# bins
# (-0.037, 3.7]  9196  31832  8644  5356  45074
# (7.4, 11.1]    1801   2645  1229   717   3139
# (11.1, 14.8]   3127   2994  2557  1813  14677
# (18.5, 22.2]    687    920  1267  1088  11655
# (22.2, 25.9]    174    259   404   403   4335
# (29.6, 33.3]     15     39    53    62    523
# (33.3, 37.0]     35     56    87    56    762
#
# -----------------------------------------
# PRSWKXPNS
# Label: Work expenses
# Universe: A_AGE > 17 or HHDFMX = 1,2,46, or 47
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new           NNN    NNY   NY_   Y1Y    YNN
# bins
# (-2.064, 206.4]   6481  30475  8279  5658  29096
# (206.4, 412.8]     131    275   104    94    470
# (412.8, 619.2]     175    312   141   101    591
# (619.2, 825.6]     210    347   136   124    670
# (825.6, 1032.0]    131    225   119    86    416
# (1032.0, 1238.4]   352    504   210   178    879
# (1238.4, 1444.8]   228    252   155   108    696
# (1444.8, 1651.2]   292    336   238   161   1100
# (1651.2, 1857.6]   265    284   167   124    969
# (1857.6, 2064.0]  6770   5735  4692  2861  45278
#
# -----------------------------------------
# STATETAX_A
# Label: State income tax liability, after all credits
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                NNN    NNY    NY_   Y1Y    YNN
# bins
# (-6490.585, 19727.5]  15009  38704  14157  9429  79338
# (19727.5, 45686.0]       20     37     63    54    637
# (45686.0, 71644.5]        6      3     15     6    113
# (71644.5, 97603.0]        0      0      2     6     35
# (97603.0, 123561.5]       0      1      4     0     25
# (123561.5, 149520.0]      0      0      0     0     10
# (149520.0, 175478.5]      0      0      0     0      1
# (175478.5, 201437.0]      0      0      0     0      3
# (201437.0, 227395.5]      0      0      0     0      2
# (227395.5, 253354.0]      0      0      0     0      1
#
# -----------------------------------------
# STATETAX_B
# Label: State income tax liability, before credits
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                NNN    NNY    NY_   Y1Y    YNN
# bins
# (-253.354, 25335.4]   15017  38718  14185  9458  79632
# (25335.4, 50670.8]       12     23     38    28    377
# (50670.8, 76006.2]        6      3     12     4     83
# (76006.2, 101341.6]       0      0      2     5     39
# (101341.6, 126677.0]      0      1      4     0     18
# (126677.0, 152012.4]      0      0      0     0      9
# (152012.4, 177347.8]      0      0      0     0      1
# (177347.8, 202683.2]      0      0      0     0      3
# (202683.2, 228018.6]      0      0      0     0      2
# (228018.6, 253354.0]      0      0      0     0      1
#
# -----------------------------------------
# TAX_INC
# Label: Taxable income amount
# Universe: Tax unit head or dependent filer
# Type: Continuous
# Topic: Income
# Subtopic: Tax model items
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                  NNN    NNY    NY_   Y1Y    YNN
# bins
# (-2298.214, 229821.4]   14968  38607  14027  9280  78079
# (229821.4, 459642.8]       49    112    153   185   1604
# (459642.8, 689464.2]       11     17     34    14    250
# (689464.2, 919285.6]        5      4     10     4     78
# (919285.6, 1149107.0]       2      4     11     9     93
# (1149107.0, 1378928.4]      0      1      3     3     45
# (1378928.4, 1608749.8]      0      0      2     0      4
# (1608749.8, 1838571.2]      0      0      0     0      1
# (1838571.2, 2068392.6]      0      0      0     0      6
# (2068392.6, 2298214.0]      0      0      1     0      5
#
# -----------------------------------------
# PERLIS
# Label: Poverty level of persons (Subfamily members have primary family recode)
# Universe: All persons
# Type: Categorical
# Topic: Poverty
# Subtopic: Poverty
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                                  NNN    NNY    NY_   Y1Y    YNN
# PERLIS
# Not in poverty universe                    29    173      9    37     46
# Below poverty level                      2650  10405   1038   549   1873
# 100 - 124 percent of the poverty level    872   3558    448   302    898
# 125 - 149 percent of the poverty level    968   3113    506   303   1240
# 150 and above the poverty level         10516  21496  12240  8304  76108
#
# -----------------------------------------
# POV_UNIV
# Label: Poverty universe flag
# Universe: All persons
# Type: Categorical
# Topic: Poverty
# Subtopic: Poverty
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new                   NNN    NNY    NY_   Y1Y    YNN
# POV_UNIV
# Not in poverty universe     29    173      9    37     46
# In poverty universe      15006  38572  14232  9458  80119
#
# -----------------------------------------
# HEA
# Label: Health status
# Universe: All persons
# Type: Categorical
# Topic: Health insurance
# Subtopic: Health status
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new    NNN    NNY   NY_   Y1Y    YNN
# HEA
# Excellent  4703   8539  4173  2207  32776
# Very good  4895   9678  4540  3038  29492
# Good       4164  11856  3859  2899  15028
# Fair       1039   6158  1247  1007   2439
# Poor        234   2514   422   344    430
#
# -----------------------------------------
# SPM_ACTC
# Label: SPM units Additional Child Tax Credit
# Universe: All persons
# Type: Continuous
# Topic: Supplemental poverty measure
# Subtopic: SPM unit characteristics
# Code: Employment-based plan (GRP) | Direct-purchase plan (DIR) | Public health insurance (PUB)
# code_new             NNN    NNY    NY_   Y1Y    YNN
# bins
# (-11.104, 1110.4]  11509  28742  13080  8266  72935
# (1110.4, 2220.8]    1538   3848    513   507   3109
# (2220.8, 3331.2]    1172   3423    362   420   2223
# (3331.2, 4441.6]     583   1840    215   176   1141
# (4441.6, 5552.0]     111    387     26    55    337
# (5552.0, 6662.4]      74    314     36    56    233
# (6662.4, 7772.8]      25    111      9     2    116
# (7772.8, 8883.2]      11     41      0     1     43
# (8883.2, 9993.6]       9     32      0    12     15
# (9993.6, 11104.0]      3      7      0     0     13
#
# -----------------------------------------
